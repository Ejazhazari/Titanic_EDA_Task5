# %% [markdown]
# <a href="https://colab.research.google.com/github/Ejazhazari/Titanic_EDA_Task5/blob/main/Task5_EDA_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("train.csv")  # Make sure the file is in your working directory

# %%
df.head()
df.info()
df.describe()
df.isnull().sum()
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# ...

# %%
# Count plots
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")

sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Count")

sns.histplot(df['Age'].dropna(), kde=True)
plt.title("Age Distribution")

sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
# Out:
# Text(0.5, 1.0, 'Age vs Survival')

# %%
# Heatmap for correlation
plt.figure(figsize=(10, 6))
# Select only numerical columns for correlation calculation
numerical_df = df.select_dtypes(include=[np.number])
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")

# Pairplot (only on selected numerical columns to avoid clutter)
sns.pairplot(df[['Survived', 'Age', 'Fare', 'Pclass']])

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title("Survival Rate by Passenger Class")

sns.barplot(x='Sex', y='Survived', data=df)
plt.title("Survival Rate by Gender")

sns.barplot(x='Embarked', y='Survived', data=df)
plt.title("Survival Rate by Port of Embarkation")
# Out:
# Text(0.5, 1.0, 'Survival Rate by Port of Embarkation')
